# %% [markdown]
# # My Jupyter Notebook on IBM Watson

# %% [markdown]
# **Jokosenumi Sanusi**
#
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because i love working with data and how i could solved problems with data*

# %% [markdown]
# ### The following code shows how to plot a sin wave with maplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y,c = 'red')
plt.show()

# %% [markdown]
#  - one
#  * two
#  |table 1|table 2|
#  |----|---|
#  |cell 1|cell 2|
#
#  3. three
#  4. Four
#
#  <div class="alert alert-block alert-warning">
# <b>Example:</b> This is just an example on how to use yellow box
# </div>
#
# ~~Scratch This.~~
